# %% [markdown]
# <a href="https://colab.research.google.com/github/ltc870/MLA1_LTC/blob/main/MLA1_LTC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# # Machine Learning Assignment 1
# ## Lawrence Caudle
# ## CS-430-ON
# ## Machine Learning in the Cloud

# %% [markdown]
# Read the file into a dataset named "df" from your Google Drive

# %%
# reading the file into a dataset named df
df = pd.read_csv('/content/gdrive/MyDrive/CS430/Module1/data/weather_2012.csv')
df
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0        1/1/2012 0:00      -1.8                -3.9           86
# 1        1/1/2012 1:00      -1.8                -3.7           87
# 2        1/1/2012 2:00      -1.8                -3.4           89
# 3        1/1/2012 3:00      -1.5                -3.2           88
# 4        1/1/2012 4:00      -1.5                -3.3           88
# ...                ...       ...                 ...          ...
# 8779  12/31/2012 19:00       0.1                -2.7           81
# 8780  12/31/2012 20:00       0.2                -2.4           83
# 8781  12/31/2012 21:00      -0.5                -1.5           93
# 8782  12/31/2012 22:00      -0.2                -1.8           89
# 8783  12/31/2012 23:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                   4              8.0           101.24                   Fog
# ...

# %% [markdown]
# Write the code to display the first five rows of the dataset, the last five rows of the dataset, and a sample of five random rows from the dataset.

# %%
# first 5 rows
df.head()
# Out:
#        Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# 0  1/1/2012 0:00      -1.8                -3.9           86                4
# 1  1/1/2012 1:00      -1.8                -3.7           87                4
# 2  1/1/2012 2:00      -1.8                -3.4           89                7
# 3  1/1/2012 3:00      -1.5                -3.2           88                6
# 4  1/1/2012 4:00      -1.5                -3.3           88                7
#
#    Visibility (km)  Stn Press (kPa)               Weather
# 0              8.0           101.24                   Fog
# 1              8.0           101.24                   Fog
# 2              4.0           101.26  Freezing Drizzle,Fog
# 3              4.0           101.27  Freezing Drizzle,Fog
# 4              4.8           101.23                   Fog

# %%
# last 5 rows
df.tail()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779  12/31/2012 19:00       0.1                -2.7           81
# 8780  12/31/2012 20:00       0.2                -2.4           83
# 8781  12/31/2012 21:00      -0.5                -1.5           93
# 8782  12/31/2012 22:00      -0.2                -1.8           89
# 8783  12/31/2012 23:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %%
# sample of 5 random rows
df.sample(5)
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 6648   10/4/2012 0:00      17.0                15.1           89
# 3307  5/17/2012 19:00      14.1                 0.4           39
# 7228  10/28/2012 4:00       9.5                 6.5           82
# 6649   10/4/2012 1:00      16.1                14.7           91
# 3575  5/28/2012 23:00      13.2                 7.1           66
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# 6648               11             16.1           101.55         Cloudy
# 3307               13             48.3           101.54          Clear
# 7228               13             25.0           101.23  Mostly Cloudy
# 6649               11             16.1           101.55         Cloudy
# 3575               13             25.0           100.54  Mostly Cloudy

# %% [markdown]
# Write the code to display a list of all of the columns in the dataset.

# %%
# code that displays a list of the columns in the dataset
df_list = list(df)
df_list
# Out:
# ['Date/Time',
#  'Temp (C)',
#  'Dew Point Temp (C)',
#  'Rel Hum (%)',
#  'Wind Spd (km/h)',
#  'Visibility (km)',
#  'Stn Press (kPa)',
#  'Weather']

# %% [markdown]
# Rename the column names to {date_time, temp_c, dew_point, relative_humidity, wind_speed, visibility, pressure, and weather}

# %%
# rename the column names
df = df.rename(columns={'Date/Time':'date_time',
                   'Temp (C)':'temp_c',
                   'Dew Point Temp (C)':'dew_point',
                   'Rel Hum (%)':'relative_humidity',
                   'Wind Spd (km/h)':'wind_speed',
                   'Visibility (km)':'visibility',
                   'Stn Press (kPa)':'pressure',
                   'Weather':'weather'})
df
# Out:
#              date_time  temp_c  dew_point  relative_humidity  wind_speed  \
# 0        1/1/2012 0:00    -1.8       -3.9                 86           4
# 1        1/1/2012 1:00    -1.8       -3.7                 87           4
# 2        1/1/2012 2:00    -1.8       -3.4                 89           7
# 3        1/1/2012 3:00    -1.5       -3.2                 88           6
# 4        1/1/2012 4:00    -1.5       -3.3                 88           7
# ...                ...     ...        ...                ...         ...
# 8779  12/31/2012 19:00     0.1       -2.7                 81          30
# 8780  12/31/2012 20:00     0.2       -2.4                 83          24
# 8781  12/31/2012 21:00    -0.5       -1.5                 93          28
# 8782  12/31/2012 22:00    -0.2       -1.8                 89          28
# 8783  12/31/2012 23:00     0.0       -2.1                 86          30
#
#       visibility  pressure               weather
# ...

# %% [markdown]
# Most of the data in the dataset are numerical, write the code to get some standard statistics for each column.

# %%
# get standard statistics for each column
df.describe()
# Out:
#             temp_c    dew_point  relative_humidity   wind_speed   visibility  \
# count  8784.000000  8784.000000        8784.000000  8784.000000  8784.000000
# mean      8.798144     2.555294          67.431694    14.945469    27.664447
# std      11.687883    10.883072          16.918881     8.688696    12.622688
# min     -23.300000   -28.500000          18.000000     0.000000     0.200000
# 25%       0.100000    -5.900000          56.000000     9.000000    24.100000
# 50%       9.300000     3.300000          68.000000    13.000000    25.000000
# 75%      18.800000    11.800000          81.000000    20.000000    25.000000
# max      33.000000    24.400000         100.000000    83.000000    48.300000
#
#           pressure
# count  8784.000000
# mean    101.051623
# std       0.844005
# min      97.520000
# 25%     100.560000
# 50%     101.070000
# 75%     101.590000
# max     103.650000
